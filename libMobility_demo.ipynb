# %%
! git clone --recurse-submodules https://github.com/stochasticHydroTools/libMobility
# Out:
# fatal: destination path 'libMobility' already exists and is not an empty directory.

# %%
! sudo apt-get install libblas-dev liblapack-dev liblapacke-dev
! pip3 install pybind11[global] numpy
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libblas-dev is already the newest version (3.10.0-2ubuntu1).
# liblapack-dev is already the newest version (3.10.0-2ubuntu1).
# liblapacke-dev is already the newest version (3.10.0-2ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.9/280.9 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 117.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 108.1 MB/s eta 0:00:00
# ...

# %%
! sudo apt autoremove --purge *mkl*
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'libmkl-intel-thread' for glob '*mkl*'
# Note, selecting 'libmkl-gf-lp64' for glob '*mkl*'
# Note, selecting 'libmkl-blacs-intelmpi-lp64' for glob '*mkl*'
# Note, selecting 'intel-mkl-linktool' for glob '*mkl*'
# Note, selecting 'libmkl-scalapack-lp64' for glob '*mkl*'
# Note, selecting 'libmkl-gf-ilp64' for glob '*mkl*'
# Note, selecting 'libmkl-gnu-thread' for glob '*mkl*'
# Note, selecting 'libmkl-avx2' for glob '*mkl*'
# Note, selecting 'libmkl-full-dev' for glob '*mkl*'
# Note, selecting 'libmkl-vml-mc' for glob '*mkl*'
# Note, selecting 'intel-mkl-cluster' for glob '*mkl*'
# Note, selecting 'libmkl-mc' for glob '*mkl*'
# Note, selecting 'libmkl-rt' for glob '*mkl*'
# Note, selecting 'libmkldnn-dev' for glob '*mkl*'
# Note, selecting 'php-srmklive-flysystem-dropbox-v2' for glob '*mkl*'
# Note, selecting 'libmkl-pgi-thread' for glob '*mkl*'
# ...

# %%
! cd libMobility && git pull && pip3 install .
# Out:
# Already up to date.
# Processing /content/libMobility
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for libMobility: filename=libMobility-0.1.0-cp310-cp310-linux_x86_64.whl size=2090 sha256=6e6bd4a9818019ca4061c921326f07953ffaeeae4c9d54050c8920120f2b3c05
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0u_us0_2/wheels/cf/d3/85/605ff82350c2ee3c221d4e32905892b3fb2e3a51cc7e8e4657
# Successfully built libMobility
# ...
#   Attempting uninstall: libMobility
#     Found existing installation: libMobility 0.1.0
#     Uninstalling libMobility-0.1.0:
#       Successfully uninstalled libMobility-0.1.0
# ...

# %%
! cd libMobility/tests/ && touch pytest.ini && echo -e "[pytest]\npythonpath = /usr/local/lib/python3.10/site-packages/" > pytest.ini && pytest -xvs test_mobility_matrix.py
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.10.12, pytest-7.4.4, pluggy-1.5.0 -- /usr/bin/python3.real
# cachedir: .pytest_cache
# rootdir: /content/libMobility/tests
# configfile: pytest.ini
# plugins: anyio-3.7.1
# collected 89 items
#
# test_mobility_matrix.py::test_mobility_matrix_linear[1-1.0-SelfMobility-periodicity0] PASSED
# test_mobility_matrix.py::test_mobility_matrix_linear[1-1.0-PSE-periodicity1] PASSED
# test_mobility_matrix.py::test_mobility_matrix_linear[1-1.0-NBody-periodicity2] PASSED
# test_mobility_matrix.py::test_mobility_matrix_linear[1-1.0-DPStokes-periodicity3] PASSED
# test_mobility_matrix.py::test_mobility_matrix_linear[1-1.0-DPStokes-periodicity4] PASSED
# test_mobility_matrix.py::test_mobility_matrix_linear[1-1.0-DPStokes-periodicity5] PASSED
# test_mobility_matrix.py::test_mobility_matrix_linear[1-0.95-SelfMobility-periodicity0] PASSED
# ...
